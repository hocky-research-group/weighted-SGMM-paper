# %% [markdown]
# ## Import Libraries

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from shapeGMM import gmm_shapes
from shapeGMMTorch import torch_sgmm
from shapeGMMTorch import scripts
import MDAnalysis as md
import torch
import pickle

# %%
# Parameters
col_indx = -1   #! 3 is meta.bias, 4 is meta.rbias, -1 means use meta.fbias from colvar_reweight file
data_path = "../../"
gro_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10.gro"
traj_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10_wrapped.trr"
colvar_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10.colvars.dat"
out_dir="./"

# %% [markdown]
# ## Load MetaD Trajectory for ADP

# %%
backbone_selection_101 = "(name C and resid 1) or (name C CA N and resid 2) or (name N and resid 3)"

# load data
prmtopFileName =  data_path + gro_file
trajFiles = [data_path+traj_file]
print(trajFiles)
print(len(trajFiles))

coord = md.Universe(prmtopFileName,trajFiles)
sel_backbone_101 = coord.select_atoms(backbone_selection_101)
print("selected atom indices:", sel_backbone_101.indices)

print("Number of atoms in trajectory:", coord.atoms.n_atoms)
print("Number of frames in trajectory:",coord.trajectory.n_frames)
print("Number of atoms being analyzed:",sel_backbone_101.n_atoms)
print("Number of frames being analyzed:",coord.trajectory.n_frames)

trajData = np.empty((coord.trajectory.n_frames,sel_backbone_101.n_atoms,3),dtype=float)
count = 0

for ts in coord.trajectory:
    trajData[count,:,:] = sel_backbone_101.positions - sel_backbone_101.center_of_geometry()
    count += 1
# Out:
# ['../../run_ala2_metad_sigma0.3_height1.2_pace500_bf10_wrapped.trr']
# 1
# selected atom indices: [ 4  6  8 14 16]
# Number of atoms in trajectory: 22
# Number of frames in trajectory: 100001
# Number of atoms being analyzed: 5
# Number of frames being analyzed: 100001

# %% [markdown]
# ## load phi-psi data and bias from metad sim

# %%
if col_indx != -1:
    time, phi, psi, bias = np.loadtxt(data_path+colvar_file, usecols=(0,1,2,col_indx), unpack=True)
else:
    # loads the final bias 
    time, phi, psi, bias = np.loadtxt(data_path+"colvar_reweight", usecols=(0,1,2,3), unpack=True)
    bias -= bias.min()

time *= 0.001  # in ns

# %% [markdown]
# ## plot phi-psi

# %%
plt.figure(figsize=(3.0,2.5), dpi=150)
plt.xlabel("$\phi$ (rad)")
plt.ylabel("$\psi$ (rad)")
plt.scatter(phi[::10], psi[::10], marker=".", s=0.05, color='k', alpha=1.0)

# %% [markdown]
# ## plot different choice of metad biases

# %%
plt.figure(figsize=(3.5,2.5), dpi=120)
plt.xlabel("Time (ns)")
plt.ylabel("MetaD Bias")
plt.plot(time, bias)

# %% [markdown]
# ## plot different weights for reweighting

# %%
kbt = 0.596161 # in kcal/mol @ 300K

# calculate biases
weights = np.exp(bias/kbt)
weights /= np.sum(weights)

# %%
plt.figure(figsize=(3.5,2.5), dpi=120)
plt.xlabel("Time (ns)")
plt.ylabel("Weights")
plt.plot(time, weights)

# %% [markdown]
# ## define cluster array

# %%
cluster_array = np.arange(1,7,1).astype(int)
print("#clusters :", cluster_array)
# Out:
# #clusters : [1 2 3 4 5 6]

# %% [markdown]
# ## Perform Cross Validation

# %%
train, cv = scripts.cross_validate_cluster_scan\
(trajData, 50000, frame_weights = weights, covar_type="kronecker", cluster_array = cluster_array, n_training_sets=4, n_attempts = 10, dtype=torch.float64, device=torch.device("cuda:0"))
# Out:
# Number of frames to train each model: 50000
# Number of frames to predict each model: 50001
# Number of training sets: 4
# Number of clusters: 6
# Number of attempts per set/cluster: 10
#    Training Set      N Clusters         Attempt  Log Like per Frame    CPU Time (s)
# ------------------------------------------------------------------------------------
#               1               1               1              20.630           6.887
#               1               2               1              54.892          46.269
#               1               2               2              53.838         120.652
#               1               2               3              53.786         121.777
#               1               2               4              53.843         121.157
#               1               2               5              34.184         128.040
#               1               2               6              53.752         124.672
#               1               2               7              53.183          28.748
#               1               2               8              54.837         118.921
#               1               2               9              57.203          78.614
#               1               2              10              33.332         135.523
#               1               3               1              57.554          99.915
#               1               3               2              56.518          35.783
# Warning: ML alignment not completely converged
#               1               3               3              58.088         160.468
#               1               3               4              54.874          78.447
#               1               3               5              57.477         158.439
#               1               3               6              53.856         153.839
#               1               3               7              58.132         155.890
#               1               3               8              58.095         161.179
# Warning: ML alignment not completely converged
#               1               3               9              58.185          52.823
#               1               3              10              57.429         169.709
#               1               4               1              58.521         193.454
#               1               4               2              58.045         184.748
#               1               4               3              52.113         182.574
#               1               4               4              58.033         186.448
#               1               4               5              58.113         182.662
#               1               4               6              58.874          69.207
#               1               4               7              58.193          40.477
#               1               4               8              58.781         196.034
#               1               4               9              58.566         215.984
#               1               4              10              53.824         177.618
#               1               5               1              54.796         223.241
#               1               5               2              53.750         213.994
# Warning: ML alignment not completely converged
#               1               5               3              59.147         166.596
#               1               5               4              57.555          81.432
#               1               5               5              58.780         248.465
#               1               5               6              58.349         135.894
#               1               5               7              57.405         226.559
#               1               5               8              58.230         237.911
#               1               5               9              57.555         135.416
#               1               5              10              58.670          65.486
# Warning: ML alignment not completely converged
#               1               6               1              59.951         271.891
#               1               6               2              57.964         137.440
# Warning: ML alignment not completely converged
#               1               6               3              58.877          75.831
#               1               6               4              58.199          40.478
#               1               6               5              58.226         262.393
#               1               6               6              58.587          38.959
#               1               6               7              58.720         108.476
#               1               6               8              58.587          53.003
#               1               6               9              59.903         280.241
#               1               6              10              58.700          93.191
#               2               1               1              20.653           5.677
#               2               2               1              54.855          47.192
#               2               2               2              54.862          28.123
#               2               2               3              46.945         118.330
#               2               2               4              54.863          26.873
#               2               2               5              38.803         112.675
#               2               2               6              39.035         113.226
#               2               2               7              53.853         118.281
#               2               2               8              53.819         117.254
#               2               2               9              54.853         115.254
#               2               2              10              53.828         117.506
#               2               3               1                 nan          19.366
#               2               3               2              53.850         143.475
#               2               3               3              57.969         129.750
#               2               3               4              57.491         152.303
#               2               3               5              53.852         150.543
#               2               3               6              58.116         155.389
#               2               3               7              58.098         158.075
# Warning: ML alignment not completely converged
#               2               3               8              52.473         153.947
#               2               3               9              54.853         157.907
#               2               3              10              55.119         162.165
#               2               4               1              58.078         197.787
# Warning: ML alignment not completely converged
#               2               4               2              57.478         185.140
#               2               4               3              53.831         171.740
#               2               4               4              58.750         209.484
#               2               4               5              57.564         143.307
#               2               4               6              58.878          77.274
#               2               4               7              58.771         197.079
#               2               4               8              53.875         120.750
# Warning: ML alignment not completely converged
#               2               4               9              59.058         201.488
#               2               4              10              54.825         180.331
#               2               5               1              58.118         227.001
#               2               5               2              58.749         237.107
#               2               5               3              58.155         208.979
#               2               5               4              57.138         220.077
#               2               5               5              58.114         217.641
#               2               5               6              58.256         249.538
#               2               5               7              58.191          58.752
# Warning: ML alignment not completely converged
#               2               5               8              59.137         238.627
#               2               5               9              57.542         161.417
#               2               5              10              59.545         230.288
#               2               6               1              59.119         263.682
#               2               6               2              59.145          78.257
#               2               6               3              58.877          76.738
#               2               6               4              58.181          60.130
#               2               6               5              58.195          45.047
#               2               6               6              59.526          91.424
#               2               6               7              59.433         198.920
#               2               6               8              58.883          95.806
# Warning: ML alignment not completely converged
#               2               6               9              59.148          84.098
#               2               6              10              58.862          72.574
#               3               1               1              20.612           5.045
#               3               2               1              54.841         124.631
#               3               2               2              52.602         144.874
#               3               2               3              57.182          80.709
#               3               2               4              41.935         120.459
#               3               2               5              53.531         132.083
#               3               2               6              47.931         122.597
#               3               2               7              54.847          48.765
#               3               2               8              53.847         120.862
# Warning: ML alignment not completely converged
#               3               2               9              54.846          77.856
#               3               2              10              48.749         122.993
#               3               3               1              57.840         167.980
# Warning: ML alignment not completely converged
#               3               3               2              58.155          51.410
#               3               3               3              57.443         157.058
#               3               3               4              54.613         132.947
#               3               3               5              54.858          68.780
#               3               3               6              58.324         172.059
#               3               3               7              57.546         119.825
# Warning: ML alignment not completely converged
#               3               3               8              57.521         153.991
#               3               3               9              58.446         173.819
#               3               3              10              57.940         102.149
#               3               4               1              58.863          44.656
#               3               4               2              58.030         193.846
#               3               4               3              58.914         210.198
#               3               4               4              58.695          69.984
#               3               4               5              58.368          97.677
#               3               4               6              57.545         178.559
#               3               4               7              58.526          51.667
#               3               4               8              58.163          66.759
#               3               4               9              57.547         135.390
#               3               4              10              58.074          42.876
# Warning: ML alignment not completely converged
#               3               5               1              58.792         235.695
#               3               5               2              58.817         239.424
#               3               5               3              58.191          74.048
#               3               5               4              59.268          75.497
#               3               5               5              59.044         238.758
#               3               5               6              54.872         117.449
#               3               5               7              58.723          74.323
#               3               5               8              58.160          44.050
# Warning: ML alignment not completely converged
#               3               5               9              58.873          98.823
#               3               5              10              58.174          35.088
#               3               6               1              57.536         172.916
#               3               6               2              59.461          98.836
#               3               6               3              58.686          85.725
#               3               6               4              54.834         254.377
#               3               6               5              59.213          76.019
#               3               6               6              59.065         265.760
#               3               6               7              58.531          46.612
#               3               6               8              59.215          66.465
#               3               6               9              58.048         251.150
#               3               6              10              58.169          61.786
#               4               1               1              33.175          98.603
#               4               2               1              57.194          69.444
#               4               2               2              57.197          36.304
#               4               2               3              43.228         135.813
#               4               2               4              51.073         136.672
#               4               2               5              57.195          85.762
#               4               2               6              48.438         139.340
#               4               2               7              54.874          58.280
#               4               2               8              43.218         119.192
#               4               2               9              43.700         122.572
#               4               2              10              54.843          60.914
#               4               3               1              58.097         157.702
#               4               3               2              57.867         154.075
#               4               3               3              57.965         126.818
#               4               3               4              57.886         160.545
#               4               3               5              57.965         121.655
#               4               3               6              58.194          49.509
#               4               3               7              54.860          86.528
#               4               3               8              57.871         161.008
#               4               3               9              58.193          52.110
#               4               3              10              52.080         162.491
# Warning: ML alignment not completely converged
#               4               4               1              59.084         206.465
#               4               4               2              57.966         104.799
#               4               4               3              58.216          34.412
#               4               4               4              58.052         197.206
# Warning: ML alignment not completely converged
#               4               4               5              57.476         209.115
#               4               4               6              57.963         202.455
#               4               4               7              58.098         188.916
# Warning: ML alignment not completely converged
#               4               4               8              58.211          42.852
#               4               4               9              58.758         102.508
#               4               4              10              57.868         195.034
#               4               5               1              59.128         235.108
#               4               5               2              58.578          49.174
#               4               5               3              53.821         207.706
#               4               5               4              58.710          91.996
#               4               5               5              58.907          66.237
#               4               5               6              59.118         241.254
#               4               5               7              53.876         180.407
#               4               5               8              59.044         237.139
#               4               5               9              59.207          77.718
#               4               5              10              57.983          96.087
#               4               6               1              58.893         102.797
# Warning: ML alignment not completely converged
#               4               6               2              58.399         111.434
#               4               6               3              58.624         267.758
#               4               6               4              58.759          91.429
#               4               6               5              59.124         279.903
#               4               6               6              58.906          72.679
# Warning: ML alignment not completely converged
#               4               6               7              57.551         253.424
#               4               6               8              58.196          65.877
#               4               6               9              58.923          46.636
#               4               6              10              57.985          47.845

# %% [raw]
# # write to data files
# np.savetxt(out_dir+"train.dat", np.column_stack((cluster_array, train)))
# np.savetxt(out_dir+"cv.dat", np.column_stack((cluster_array, cv)))

# %%
train = np.loadtxt("train.dat")[:,1:]
cv = np.loadtxt("cv.dat")[:,1:]

# %%
# create figure
plt.figure(figsize=(3.5,2.8), dpi= 150, facecolor='w', edgecolor='k')

# train
train_mean = np.mean(train, axis=1)
train_std = np.std(train, axis=1)

plt.errorbar(cluster_array,train_mean, train_std, fmt='-o', lw=3, capsize=3, label="Training")

# cv
cv_mean = np.mean(cv, axis=1)
cv_std = np.std(cv, axis=1)

plt.errorbar(cluster_array, cv_mean, cv_std, fmt='--x', lw=3, capsize=3, label="Cross Validation")

plt.grid(which='major', axis='both', color='#808080', linestyle='--')
plt.ylabel("Log Likelihood per Frame")
plt.xlabel("Number of Clusters")
plt.tick_params(axis='both')
plt.legend(loc="lower right")
plt.tight_layout()
