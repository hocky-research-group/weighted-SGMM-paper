# %% [markdown]
# ## Import Libraries

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from shapeGMM import gmm_shapes
from shapeGMMTorch import torch_sgmm
from shapeGMMTorch import scripts
import MDAnalysis as md
import torch
import pickle

# %%
# Parameters
col_indx = 4  #! 3 is meta.bias, 4 is meta.rbias, -1 means use meta.fbias from colvar_reweight file
data_path = "../../"
gro_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10.gro"
traj_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10_wrapped.trr"
colvar_file = "run_ala2_metad_sigma0.3_height1.2_pace500_bf10.colvars.dat"
out_dir ="./"

# %% [markdown]
# ## Load MetaD Trajectory for ADP

# %%
backbone_selection_101 = "(name C and resid 1) or (name C CA N and resid 2) or (name N and resid 3)"

# load data
prmtopFileName =  data_path + gro_file
trajFiles = [data_path+traj_file]
print(trajFiles)
print(len(trajFiles))

coord = md.Universe(prmtopFileName,trajFiles)
sel_backbone_101 = coord.select_atoms(backbone_selection_101)
print("selected atom indices:", sel_backbone_101.indices)

print("Number of atoms in trajectory:", coord.atoms.n_atoms)
print("Number of frames in trajectory:",coord.trajectory.n_frames)
print("Number of atoms being analyzed:",sel_backbone_101.n_atoms)
print("Number of frames being analyzed:",coord.trajectory.n_frames)

trajData = np.empty((coord.trajectory.n_frames,sel_backbone_101.n_atoms,3),dtype=float)
count = 0

for ts in coord.trajectory:
    trajData[count,:,:] = sel_backbone_101.positions - sel_backbone_101.center_of_geometry()
    count += 1
# Out:
# ['../../run_ala2_metad_sigma0.3_height1.2_pace500_bf10_wrapped.trr']
# 1
# selected atom indices: [ 4  6  8 14 16]
# Number of atoms in trajectory: 22
# Number of frames in trajectory: 100001
# Number of atoms being analyzed: 5
# Number of frames being analyzed: 100001

# %% [markdown]
# ## load phi-psi data and bias from metad sim

# %%
if col_indx != -1:
    time, phi, psi, bias = np.loadtxt(data_path+colvar_file, usecols=(0,1,2,col_indx), unpack=True)
else:
    # loads the final bias 
    time, phi, psi, bias = np.loadtxt(data_path+"colvar_reweight", usecols=(0,1,2,3), unpack=True)
    bias -= bias.min()

time *= 0.001  # in ns

# %% [markdown]
# ## plot phi-psi

# %%
plt.figure(figsize=(3.0,2.5), dpi=150)
plt.xlabel("$\phi$ (rad)")
plt.ylabel("$\psi$ (rad)")
plt.scatter(phi[::10], psi[::10], marker=".", s=0.05, color='k', alpha=1.0)

# %% [markdown]
# ## plot different choice of metad biases

# %%
plt.figure(figsize=(3.5,2.5), dpi=120)
plt.xlabel("Time (ns)")
plt.ylabel("MetaD Bias")
plt.plot(time, bias)

# %% [markdown]
# ## plot different weights for reweighting

# %%
kbt = 0.596161 # in kcal/mol @ 300K

# calculate biases
weights = np.exp(bias/kbt)
weights /= np.sum(weights)

# %%
plt.figure(figsize=(3.5,2.5), dpi=120)
plt.xlabel("Time (ns)")
plt.ylabel("Weights")
plt.plot(time, weights)

# %% [markdown]
# ## define cluster array

# %%
cluster_array = np.arange(1,7,1).astype(int)
print("#clusters :", cluster_array)
# Out:
# #clusters : [1 2 3 4 5 6]

# %% [markdown]
# ## Perform Cross Validation

# %%
train, cv = scripts.cross_validate_cluster_scan\
(trajData, 50000, frame_weights = weights, covar_type="kronecker", cluster_array = cluster_array, n_training_sets=4, n_attempts = 10, dtype=torch.float64, device=torch.device("cuda:0"))
# Out:
# Number of frames to train each model: 50000
# Number of frames to predict each model: 50001
# Number of training sets: 4
# Number of clusters: 6
# Number of attempts per set/cluster: 10
#    Training Set      N Clusters         Attempt  Log Like per Frame    CPU Time (s)
# ------------------------------------------------------------------------------------
#               1               1               1              32.431         103.521
#               1               2               1              48.227         117.677
#               1               2               2              54.485          34.641
#               1               2               3              47.941         139.696
#               1               2               4              54.778         142.216
#               1               2               5              49.410         164.126
#               1               2               6              43.647         143.933
# Warning: ML alignment not completely converged
#               1               2               7              54.835         155.137
#               1               2               8              53.216          34.492
#               1               2               9              41.276         137.644
#               1               2              10              45.561         135.537
# Warning: ML alignment not completely converged
#               1               3               1              57.905          99.365
# Warning: ML alignment not completely converged
#               1               3               2              58.146          66.518
#               1               3               3              57.535         182.288
#               1               3               4              47.000         207.116
#               1               3               5              57.455         198.114
#               1               3               6              57.974         204.664
#               1               3               7              58.475          54.812
#               1               3               8              58.132          60.408
#               1               3               9              57.819         182.099
# Warning: ML alignment not completely converged
#               1               3              10              57.493         192.691
# Warning: ML alignment not completely converged
#               1               4               1              58.049         223.448
# Warning: ML alignment not completely converged
#               1               4               2              57.546         187.933
#               1               4               3              58.478          35.653
#               1               4               4              58.121         222.341
# Warning: ML alignment not completely converged
#               1               4               5              58.124          66.673
#               1               4               6                 nan          30.637
#               1               4               7              55.116         221.709
#               1               4               8              58.057         246.249
#               1               4               9              58.138          50.405
# Warning: ML alignment not completely converged
#               1               4              10              58.124          66.337
#               1               5               1              58.863          86.426
#               1               5               2              59.443         293.051
#               1               5               3                 nan         250.060
# Warning: ML alignment not completely converged
#               1               5               4              58.150          82.806
# Warning: ML alignment not completely converged
#               1               5               5              59.433         300.627
#               1               5               6              57.567          99.021
#               1               5               7              58.169          59.457
#               1               5               8              58.483          62.977
#               1               5               9              58.885          73.769
#               1               5              10              57.557         179.825
#               1               6               1              57.797         176.558
# Warning: ML alignment not completely converged
#               1               6               2              59.167         125.104
# Warning: ML alignment not completely converged
#               1               6               3              58.692         200.495
#               1               6               4              57.814         283.374
#               1               6               5              59.047         317.452
#               1               6               6              58.848         129.355
# Warning: ML alignment not completely converged
#               1               6               7              58.896          69.457
#               1               6               8              58.654         157.814
#               1               6               9              57.471         268.292
#               1               6              10              59.471         121.075
#               2               1               1              20.647           6.253
#               2               2               1              53.863         142.343
#               2               2               2              47.256         142.264
#               2               2               3              56.528          37.919
#               2               2               4              54.248          26.281
#               2               2               5              53.860         144.662
#               2               2               6              53.860         141.478
#               2               2               7              53.793         159.023
#               2               2               8              53.865         125.603
#               2               2               9              52.403         137.343
# Warning: ML alignment not completely converged
#               2               2              10              52.014         149.901
#               2               3               1              54.539         185.195
#               2               3               2              53.958         189.708
#               2               3               3              34.327         190.258
#               2               3               4              57.838         195.380
#               2               3               5              53.938          28.280
#               2               3               6              58.151          62.547
#               2               3               7              58.152          57.083
#               2               3               8              58.152          58.968
#               2               3               9              53.905          65.730
#               2               3              10              57.870         186.562
#               2               4               1              58.154          61.740
#               2               4               2              58.394         226.012
#               2               4               3              58.609         240.996
#               2               4               4              58.457         237.883
#               2               4               5              58.028          68.452
#               2               4               6              58.152          69.749
#               2               4               7              58.038         236.012
#               2               4               8              58.164         199.351
#               2               4               9              57.496         223.413
#               2               4              10              58.352         105.589
#               2               5               1              59.022         291.339
#               2               5               2              58.903          63.689
#               2               5               3              59.299         279.572
#               2               5               4              53.863         243.947
#               2               5               5              57.822         270.300
# Warning: ML alignment not completely converged
#               2               5               6              58.851          99.929
#               2               5               7              58.167          66.656
# Warning: ML alignment not completely converged
#               2               5               8              59.081         302.288
#               2               5               9              58.026         254.423
#               2               5              10              58.046         256.517
#               2               6               1              58.186          82.564
#               2               6               2              57.825         126.410
#               2               6               3              58.691         179.377
#               2               6               4              59.226          90.810
#               2               6               5              58.677         124.049
# Warning: ML alignment not completely converged
#               2               6               6              58.904          87.429
#               2               6               7              59.068         348.884
#               2               6               8              59.044         342.459
#               2               6               9              58.034         299.920
#               2               6              10              59.147          84.518
#               3               1               1              20.611           6.138
#               3               2               1              53.655         157.693
#               3               2               2              53.007          61.538
#               3               2               3              53.007          65.869
#               3               2               4              51.394         147.939
#               3               2               5              57.173         113.944
#               3               2               6              54.882         138.227
#               3               2               7              57.173         103.771
#               3               2               8              57.173         102.947
#               3               2               9              54.872         103.019
#               3               2              10              53.007          60.101
#               3               3               1              57.924          97.377
#               3               3               2              53.883         181.295
#               3               3               3              58.213          48.829
#               3               3               4              53.233          74.909
#               3               3               5              58.398         203.942
#               3               3               6              58.413         197.034
#               3               3               7              57.924         170.493
#               3               3               8              58.191          70.772
#               3               3               9              53.909         180.406
# Warning: ML alignment not completely converged
#               3               3              10              57.551         148.114
# Warning: ML alignment not completely converged
#               3               4               1              59.342          78.033
#               3               4               2              58.223          51.846
#               3               4               3              59.210         104.405
# Warning: ML alignment not completely converged
#               3               4               4              58.925          95.745
#               3               4               5              58.195          61.419
# Warning: ML alignment not completely converged
#               3               4               6              59.047          99.632
# Warning: ML alignment not completely converged
# Warning: ML alignment not completely converged
#               3               4               7                 nan          32.381
# Warning: ML alignment not completely converged
#               3               4               8              54.890         185.581
# Warning: ML alignment not completely converged
#               3               4               9              58.925          98.289
#               3               4              10              51.252         239.831
#               3               5               1              53.887         149.853
#               3               5               2              57.927          98.867
#               3               5               3              54.627         112.308
#               3               5               4              58.444          68.373
#               3               5               5              58.194          59.745
#               3               5               6              58.949          59.452
#               3               5               7              57.948          71.897
#               3               5               8              59.245          69.625
#               3               5               9              57.558         265.208
#               3               5              10              58.883         287.169
#               3               6               1              58.854         111.406
#               3               6               2              58.404          90.434
#               3               6               3              58.442         299.946
# Warning: ML alignment not completely converged
#               3               6               4              59.493         162.660
#               3               6               5              59.062         111.989
#               3               6               6              58.933          68.291
# Warning: ML alignment not completely converged
#               3               6               7              58.198          60.832
#               3               6               8              59.068          82.755
#               3               6               9              59.993         193.952
# Warning: ML alignment not completely converged
#               3               6              10                 nan          30.526
#               4               1               1              20.607           6.513
#               4               2               1              48.197         156.443
#               4               2               2              57.102         103.376
#               4               2               3              57.101          93.924
#               4               2               4              54.510          44.813
#               4               2               5              54.240          31.029
#               4               2               6              53.028          68.021
#               4               2               7              57.101         104.062
#               4               2               8              54.856         164.119
#               4               2               9              32.269         169.738
# Warning: ML alignment not completely converged
#               4               2              10              54.863         140.561
#               4               3               1              58.056         201.726
#               4               3               2              58.125          50.801
#               4               3               3              54.619         159.931
#               4               3               4              53.684         186.335
#               4               3               5              54.876          82.486
#               4               3               6              53.851         179.857
#               4               3               7              57.494          99.137
#               4               3               8              58.006         214.461
#               4               3               9              58.126          61.181
#               4               3              10              57.493         119.744
#               4               4               1              57.428         240.050
#               4               4               2              57.495         168.242
#               4               4               3              58.415         234.555
#               4               4               4              53.865         182.685
#               4               4               5              58.230         267.584
# Warning: ML alignment not completely converged
#               4               4               6              58.114          64.250
# Warning: ML alignment not completely converged
#               4               4               7              58.889         238.743
# Warning: ML alignment not completely converged
#               4               4               8              58.110          70.940
#               4               4               9              59.192          49.349
#               4               4              10              53.868         113.139
#               4               5               1              57.885         136.438
#               4               5               2              59.101         104.112
#               4               5               3              57.424         300.766
#               4               5               4              58.386         264.992
#               4               5               5              58.729         286.733
#               4               5               6              58.869          71.398
#               4               5               7              52.192         286.603
#               4               5               8              58.388         291.329
# Warning: ML alignment not completely converged
#               4               5               9              58.841          78.953
#               4               5              10              58.481          59.230
#               4               6               1              57.363         299.833
# Warning: ML alignment not completely converged
#               4               6               2              59.384         149.323
#               4               6               3              58.120          75.454
#               4               6               4              58.134          62.879
#               4               6               5              57.919         141.844
#               4               6               6              54.863         114.944
#               4               6               7              57.453         297.877
#               4               6               8              59.505         110.290
# Warning: ML alignment not completely converged
#               4               6               9              59.674          93.412
#               4               6              10              58.667         119.333

# %%
# write to data files
np.savetxt(out_dir+"train.dat", np.column_stack((cluster_array, train)))
np.savetxt(out_dir+"cv.dat", np.column_stack((cluster_array, cv)))

# %%
train = np.loadtxt("train.dat")[:,1:]
cv = np.loadtxt("cv.dat")[:,1:]

# %%
# create figure
plt.figure(figsize=(3.5,2.8), dpi= 150, facecolor='w', edgecolor='k')

# train
train_mean = np.mean(train, axis=1)
train_std = np.std(train, axis=1)

plt.errorbar(cluster_array,train_mean, train_std, fmt='-o', lw=3, capsize=3, label="Training")

# cv
cv_mean = np.mean(cv, axis=1)
cv_std = np.std(cv, axis=1)

plt.errorbar(cluster_array, cv_mean, cv_std, fmt='--x', lw=3, capsize=3, label="Cross Validation")

plt.grid(which='major', axis='both', color='#808080', linestyle='--')
plt.ylabel("Log Likelihood per Frame")
plt.xlabel("Number of Clusters")
plt.tick_params(axis='both')
plt.legend(loc="lower right")
plt.tight_layout()
